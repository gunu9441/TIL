# %% [markdown]
# # Loading data

# %%
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self):
        self.x_data = [[73, 80, 75],
                       [93, 88, 93],
                       [89, 91, 90],
                       [96, 98, 100],
                       [73, 66, 70]]
        self.y_data = [[152], [185], [180], [196], [142]]
        
    def __len__(self):
        return len(self.x_data)
    
    def __getitem__(self, idx):
        x = torch.FloatTensor(self.x_data[idx])
        y = torch.FloatTensor(self.y_data[idx])
        
        return x, y
    
dataset = CustomDataset()

# %%
dataloader = DataLoader(dataset, batch_size=2,shuffle=True,)

# %%
# initialized model
W = torch.zeros((3,1), requires_grad = True)
b = torch.zeros(1,requires_grad = True)
# optimizer
optimizer = torch.optim.SGD([W,b], lr =1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)
        x_train, y_train = samples
        hypothesis = x_train.matmul(W) + b
        cost = torch.mean((hypothesis - y_train)**2)
    
        # improve H(x) with cost
        optimizer.zero_grad()  #initialized gradient with 0
        cost.backward()        #calculate gradient by cost's differential
        optimizer.step()       #gradient descent
    
        print("Ephoch {:4d}/{} Batch: {}/{}, Cost: {:.6f}".format(epoch, nb_epochs, batch_idx+1, len(dataloader), cost.item()))
# Out:
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Ephoch    0/20 Batch: 1/3, Cost: 36320.500000
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Ephoch    0/20 Batch: 2/3, Cost: 5834.200195
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch    0/20 Batch: 3/3, Cost: 1595.437866
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Ephoch    1/20 Batch: 1/3, Cost: 1037.317627
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Ephoch    1/20 Batch: 2/3, Cost: 315.887268
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Ephoch    1/20 Batch: 3/3, Cost: 138.603775
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Ephoch    2/20 Batch: 1/3, Cost: 20.064636
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Ephoch    2/20 Batch: 2/3, Cost: 14.663375
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch    2/20 Batch: 3/3, Cost: 10.084520
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Ephoch    3/20 Batch: 1/3, Cost: 0.245612
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Ephoch    3/20 Batch: 2/3, Cost: 4.998861
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Ephoch    3/20 Batch: 3/3, Cost: 1.504643
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Ephoch    4/20 Batch: 1/3, Cost: 1.500977
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Ephoch    4/20 Batch: 2/3, Cost: 0.977720
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch    4/20 Batch: 3/3, Cost: 5.307436
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Ephoch    5/20 Batch: 1/3, Cost: 1.875060
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Ephoch    5/20 Batch: 2/3, Cost: 2.471475
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Ephoch    5/20 Batch: 3/3, Cost: 1.872875
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Ephoch    6/20 Batch: 1/3, Cost: 1.852414
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Ephoch    6/20 Batch: 2/3, Cost: 1.758663
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Ephoch    6/20 Batch: 3/3, Cost: 1.661918
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Ephoch    7/20 Batch: 1/3, Cost: 0.361126
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Ephoch    7/20 Batch: 2/3, Cost: 2.815830
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Ephoch    7/20 Batch: 3/3, Cost: 2.462528
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Ephoch    8/20 Batch: 1/3, Cost: 1.405867
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Ephoch    8/20 Batch: 2/3, Cost: 3.233543
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Ephoch    8/20 Batch: 3/3, Cost: 1.621410
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Ephoch    9/20 Batch: 1/3, Cost: 1.780026
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Ephoch    9/20 Batch: 2/3, Cost: 2.359852
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Ephoch    9/20 Batch: 3/3, Cost: 0.622547
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Ephoch   10/20 Batch: 1/3, Cost: 0.396593
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Ephoch   10/20 Batch: 2/3, Cost: 1.931994
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch   10/20 Batch: 3/3, Cost: 4.224751
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Ephoch   11/20 Batch: 1/3, Cost: 1.341274
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Ephoch   11/20 Batch: 2/3, Cost: 3.278768
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Ephoch   11/20 Batch: 3/3, Cost: 1.648412
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Ephoch   12/20 Batch: 1/3, Cost: 1.688819
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Ephoch   12/20 Batch: 2/3, Cost: 2.299416
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Ephoch   12/20 Batch: 3/3, Cost: 1.263360
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Ephoch   13/20 Batch: 1/3, Cost: 0.199764
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Ephoch   13/20 Batch: 2/3, Cost: 2.196914
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch   13/20 Batch: 3/3, Cost: 4.403619
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Ephoch   14/20 Batch: 1/3, Cost: 1.391584
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Ephoch   14/20 Batch: 2/3, Cost: 2.343419
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Ephoch   14/20 Batch: 3/3, Cost: 1.002046
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Ephoch   15/20 Batch: 1/3, Cost: 1.269470
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Ephoch   15/20 Batch: 2/3, Cost: 2.316415
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Ephoch   15/20 Batch: 3/3, Cost: 1.156504
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Ephoch   16/20 Batch: 1/3, Cost: 1.673193
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Ephoch   16/20 Batch: 2/3, Cost: 2.312006
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Ephoch   16/20 Batch: 3/3, Cost: 0.636445
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Ephoch   17/20 Batch: 1/3, Cost: 2.437286
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Ephoch   17/20 Batch: 2/3, Cost: 1.436069
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Ephoch   17/20 Batch: 3/3, Cost: 0.609184
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Ephoch   18/20 Batch: 1/3, Cost: 2.365380
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Ephoch   18/20 Batch: 2/3, Cost: 1.315794
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Ephoch   18/20 Batch: 3/3, Cost: 1.333775
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Ephoch   19/20 Batch: 1/3, Cost: 1.788774
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Ephoch   19/20 Batch: 2/3, Cost: 0.569850
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Ephoch   19/20 Batch: 3/3, Cost: 5.239877
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Ephoch   20/20 Batch: 1/3, Cost: 2.321582
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Ephoch   20/20 Batch: 2/3, Cost: 1.214713
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Ephoch   20/20 Batch: 3/3, Cost: 2.396553
